# %% [markdown]
# # UHIMP - Phase 1: Data Exploration
# Explore harmonized raster stack and training tables before modeling.

# %%
import pandas as pd
import geopandas as gpd

# df = pd.read_csv('../data/training_tables/delhi_lst_training_points_2024.csv')
# df.describe()
